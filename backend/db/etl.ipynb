# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### AHA Data

# %%
# core + capabilities
keep = [
    'ID',        # hospital_id
    'MNAME',     # name
    'MLOCADDR',  # address
    'MLOCCITY',  # city
    'MSTATE',    # state
    'MLOCZIP',   # zip
    'LAT',       # latitude
    'LONG',      # longitude
    'EMDEPHOS',  # ED present?
    'TRAUMHOS',  # trauma center?
    'TRAUML90',  # trauma level
    'HOSPBD',    # total beds
    'YEAR',      # year 
    # new capability columns:
    'CTSCNHOS',  # CT scanners
    'MSCTHOS',   # multislice CT <64
    'MSCTGHOS',  # multislice CT ≥64
    'MRIHOS',    # MRI units
    'PETCTHOS',  # PET/CT units
    'SPECTHOS',  # SPECT units
    'ULTSNHOS',  # ultrasound units
    'BRNBD',     # burn care beds
    'MSICBD',    # med/surg ICU beds
    'NICBD',     # neonatal ICU beds
    'PEDICBD'    # pediatric ICU beds
]

# %%
# Load the CSV file into a pandas DataFrame
aha_df = pd.read_csv('data/raw/albert_aha.csv', usecols=keep, encoding='latin1')

# Only keep year 2023
aha_df = aha_df[aha_df['YEAR'] == 2023]
display(aha_df.head())

# display 10 random rows
display(aha_df.sample(10))

print(aha_df.shape)
# Out:
# /var/folders/sb/ybsfm6hs7398knjpcps4h9240000gn/T/ipykernel_5903/1475126400.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   aha_df = pd.read_csv('data/raw/albert_aha.csv', usecols=keep, encoding='latin1')
#          ID                            MNAME  YEAR  \
# 2   6030010               Kwajalein Hospital  2023
# 5   6040001  Wilma N. Vazquez Medical Center  2023
# 8   6040002           Hospital San Francisco  2023
# 11  6040004            HIMA San Pablo Caguas  2023
# 14  6040005         Hospital Buen Samaritano  2023
#
#                                  MLOCADDR         MLOCCITY  MSICBD  NICBD  \
# 2                U S Army Kwajalein Atoll  Kwajalein Atoll     NaN    NaN
# 5         KM 39 1/2 Road 2, Call Box 7001        Vega Baja     0.0    0.0
# 8                    371 Avenida De Diego         San Juan     NaN    NaN
# 11                    Avenida Munoz Marin           Caguas     NaN    NaN
# 14  Carr #2 Km 141-1 Ave Severiano Cuevas        Aguadilla     NaN    NaN
#
#     PEDICBD  BRNBD  HOSPBD  ...  MRIHOS  MSCTHOS  MSCTGHOS  PETCTHOS  \
# 2       NaN    NaN    14.0  ...     NaN      NaN       NaN       NaN
# 5       0.0    0.0    68.0  ...     0.0      0.0       0.0       0.0
# 8       NaN    NaN   133.0  ...     NaN      NaN       NaN       NaN
# 11      NaN    NaN   415.0  ...     NaN      NaN       NaN       NaN
# 14      NaN    NaN   145.0  ...     NaN      NaN       NaN       NaN
#
#     SPECTHOS  ULTSNHOS  MSTATE      LAT      LONG     MLOCZIP
# 2        NaN       NaN      MH   8.7167  167.7333       96555
# 5        0.0       0.0      PR  18.4533  -66.4069       00694
# 8        NaN       NaN      PR  18.3986  -66.0389  00923-1711
# 11       NaN       NaN      PR  18.2381  -66.0372       00726
# 14       NaN       NaN      PR  18.4553  -67.1319       00603
#
# [5 rows x 24 columns]
#             ID                                 MNAME  YEAR  \
# 7973   6451900               Tomah VA Medical Center  2023
# 12341  6720192                                 Avala  2023
# 5977   6412345            CMH Regional Health System  2023
# 17844  6931758               Greater Los Angeles HCS  2023
# 5583   6410505                 The Woods at Parkside  2023
# 13390  6740152               Sunrise Canyon Hospital  2023
# 17081  6920418  Legacy Good Samaritan Medical Center  2023
# 2875   6340023  Spotsylvania Regional Medical Center  2023
# 6159   6420225         Franciscan Health Crown Point  2023
# 5      6040001       Wilma N. Vazquez Medical Center  2023
#
#                               MLOCADDR        MLOCCITY  MSICBD  NICBD  \
# 7973          500 East Veterans Street           Tomah     NaN    NaN
# 12341              67252 Industry Lane       Covington     NaN    NaN
# 5977              610 West Main Street      Wilmington     NaN    NaN
# 17844         11301 Wilshire Boulevard     Los Angeles     NaN    NaN
# 5583            349 Olde Ridenour Road         Gahanna     NaN    NaN
# 13390                   1950 Aspen Ave         Lubbock     0.0    0.0
# 17081              1015 NW 22nd Avenue        Portland    28.0    0.0
# 2875         4600 Spotsylvania Parkway  Fredericksburg    12.0    4.0
# 6159            1201 South Main Street     Crown Point     NaN    NaN
# 5      KM 39 1/2 Road 2, Call Box 7001       Vega Baja     0.0    0.0
#
#        PEDICBD  BRNBD  HOSPBD  ...  MRIHOS  MSCTHOS  MSCTGHOS  PETCTHOS  \
# 7973       NaN    NaN    71.0  ...     NaN      NaN       NaN       NaN
# 12341      NaN    NaN    21.0  ...     NaN      NaN       NaN       NaN
# 5977       NaN    NaN   165.0  ...     NaN      NaN       NaN       NaN
# 17844      NaN    NaN   422.0  ...     NaN      NaN       NaN       NaN
# 5583       NaN    NaN    50.0  ...     NaN      NaN       NaN       NaN
# 13390      0.0    0.0    30.0  ...     0.0      0.0       0.0       0.0
# 17081      0.0    0.0   236.0  ...     1.0      1.0       1.0       1.0
# 2875       0.0    0.0   137.0  ...     1.0      0.0       1.0       0.0
# 6159       NaN    NaN   254.0  ...     NaN      NaN       NaN       NaN
# 5          0.0    0.0    68.0  ...     0.0      0.0       0.0       0.0
#
#        SPECTHOS  ULTSNHOS  MSTATE      LAT      LONG     MLOCZIP
# 7973        NaN       NaN      WI  44.0036  -90.4934  54660-3105
# 12341       NaN       NaN      LA  30.4058  -90.0830  70433-8704
# 5977        NaN       NaN      OH  39.4436  -83.8400  45177-2125
# 17844       NaN       NaN      CA  34.0527 -118.4530  90073-1003
# 5583        NaN       NaN      OH  40.0271  -82.8818  43230-2528
# 13390       0.0       0.0      TX  33.5734 -101.8080  79404-1211
# 17081       1.0       1.0      OR  45.5303 -122.6980  97210-3099
# 2875        0.0       1.0      VA  38.2182  -77.4961  22408-7762
# 6159        NaN       NaN      IN  41.3958  -87.3676  46307-8483
# 5           0.0       0.0      PR  18.4533  -66.4069       00694
#
# [10 rows x 24 columns]
# (6166, 24)

# %%
# get number of row with no NaN values
print(aha_df.isna().sum())
# Out:
# ID             0
# MNAME          0
# YEAR           0
# MLOCADDR       0
# MLOCCITY       0
# MSICBD      2430
# NICBD       2430
# PEDICBD     2430
# BRNBD       2430
# HOSPBD         0
# EMDEPHOS    2430
# TRAUMHOS    2430
# TRAUML90    4630
# CTSCNHOS    2430
# MRIHOS      2430
# MSCTHOS     2430
# MSCTGHOS    2430
# PETCTHOS    2430
# SPECTHOS    2430
# ULTSNHOS    2430
# MSTATE         0
# LAT            0
# LONG           0
# MLOCZIP        0
# dtype: int64

# %%
# push to MySQL
engine = create_engine("mysql+pymysql://root:pass@localhost:3306/hospitals")
aha_df.to_sql('AHA_Hospitals', engine, if_exists='replace', index=False)
